# %%
from __future__ import division
import matplotlib.pyplot as plt
get_ipython().magic(u'matplotlib inline')
import numpy as np
import scipy as sp
import scipy.linalg
import time
import random
import tensorflow as tf
from termcolor import colored
def print_np(x):
    print ("Type is %s" % (type(x)))
    print ("Shape is %s" % (x.shape,))
    print ("Values are: \n%s" % (x))

# %%
import model
import cost
from iLQR import iLQR

# %%
x_t = np.zeros(2)
x_t[0] = 0.0
x_t[1] = 3.0
ix = 12
iu = 4
N = 500
myModel = model.quadrotor('Hello')
myCost = cost.quadrotor('Hello',x_t,N,myModel)

# %%
maxIterIn = 100
maxIterOut = 100

x0 = np.zeros(12)
x0[0] = -2.0 # -2.0
x0[1] = -0.5 # -0.5
x0[2] = 1.0
x0[5] = 0.0

u0 = np.ones((N,iu))
i1 = iLQR('unicycle',N,maxIterIn,maxIterOut,myModel,myCost)
x, u, Quu_save, Quu_inv_save, L, l, lam, Mu = i1.update(x0,u0)
# Out:
# Outloop iteration == 0
#
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 399
# Cholesky failed at 398
# iteration   cost        reduction   expected    gradient    log10(lambda)
# 0           1.31178e+08 1.19e+05    1.19e+05    0.331       7.3
# 1           1.31059e+08 1.93e+05    1.92e+05    0.53        7.1
# 2           1.30865e+08 5.11e+05    5e+05       1.36        6.7
# Cholesky failed at 500
# Cholesky failed at 499
# 3           1.30355e+08 5.26e+05    5.15e+05    1.39        6.7
# Cholesky failed at 491
# Cholesky failed at 487
# 4           1.29828e+08 2.07e+05    2.06e+05    0.552       7.1
# 5           1.29621e+08 3.38e+05    3.34e+05    0.889       6.9
# Cholesky failed at 491
# 6           1.29283e+08 5.59e+05    5.47e+05    1.44        6.7
# Cholesky failed at 492
# 7           1.28724e+08 5.76e+05    5.63e+05    1.47        6.7
# Cholesky failed at 486
# Cholesky failed at 485
# 8           1.28148e+08 2.27e+05    2.25e+05    0.592       7.1
# 9           1.27921e+08 3.7e+05     3.65e+05    0.959       6.9
# Cholesky failed at 497
# Cholesky failed at 495
# 10          1.27551e+08 2.34e+05    2.31e+05    0.616       7.1
# 11          1.27318e+08 3.81e+05    3.76e+05    1           6.9
# Cholesky failed at 499
# Cholesky failed at 498
# 12          1.26936e+08 2.41e+05    2.39e+05    0.645       7.1
# 13          1.26695e+08 3.93e+05    3.87e+05    1.05        6.9
# Cholesky failed at 493
# 14          1.26302e+08 6.51e+05    6.35e+05    1.72        6.7
# Cholesky failed at 497
# 15          1.25651e+08 6.74e+05    6.56e+05    1.8         6.7
# Cholesky failed at 495
# Cholesky failed at 495
# 16          1.24977e+08 2.65e+05    2.63e+05    0.73        7.1
# 48          9.68184e+07 6.36e+06    4.8e+06     6.26        6.5
# Cholesky failed at 498
# Cholesky failed at 445
# 49          9.04605e+07 5.94e+06    4.79e+06    5.13        6.7
# 50          8.45161e+07 1.33e+07    9.28e+06    9.57        6.5
# Cholesky failed at 497
# 51          7.12295e+07 2.04e+07    1.47e+07    17.6        6.3
# 52          5.08604e+07 1.25e+07    1.17e+07    20.2        6.1
# 53          3.8337e+07  1.22e+07    1.21e+07    24.7        5.7
# 54          2.61691e+07 1.08e+07    1.18e+07    44          5.1
# 55          1.53452e+07 6.3e+06     7.65e+06    36.4        4.3
# 56          9.04262e+06 5.73e+06    5.36e+06    44.4        3.3
# 57          3.31088e+06 2.92e+06    2.96e+06    56.7        2.0
# 58          392978      1.52e+05    1.59e+05    55.4        0.6
# 59          241446      3.47e+04    3.96e+04    44.6        -1.0
# 60          206705      3.83e+04    3.88e+04    26.5        -2.9
# 61          168429      487         1.69e+04    17.1        -4.9
# 62          167942      9.23e+03    1.32e+04    21.6        -7.1
# iLQR.py:340: RuntimeWarning: divide by zero encountered in log10
#   print("%-12d%-12.6g%-12.3g%-12.3g%-12.3g%-12.1f" % ( iteration,np.sum(self.c),dcost,expected,g_norm,np.log10(self.lamda)) )
# 63          158716      6.85e+03    1.24e+04    12.1        -inf
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# Cholesky failed at 49
# 64          151865      723         1.9e+03     6.39        1.1
# 65          151142      3.45e+03    6.67e+03    5.52        0.9
# 66          147694      1.91e+03    6.15e+03    7.29        0.5
# 67          145785      1.74e+03    2.85e+03    8.9         -0.1
# 68          144050      4.07e+03    3.46e+03    6.34        -0.9
# 69          139976      970         1.57e+03    5.88        -1.9
# 70          139006      3.28e+03    1.92e+03    2.84        -3.1
# 71          135726      3e+03       2.79e+03    4.96        -4.6
# 72          132727      4.48e+03    3.55e+03    3.31        -6.2
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 332
# Cholesky failed at 322
# 73          128248      17          216         1.48        3.0
# 74          128231      774         633         0.459       2.8
# 75          127457      596         447         0.387       2.4
# 76          126860      689         527         0.685       1.8
# Cholesky failed at 203
# Cholesky failed at 200
# Cholesky failed at 189
# Cholesky failed at 164
# 77          126172      45.1        100         0.428       3.0
# 78          126127      256         227         0.303       2.8
# 79          125871      250         187         0.299       2.4
# 80          125621      436         319         0.469       1.8
# 81          125184      719         463         1.01        0.9
# 82          124466      768         398         0.987       -0.1
# 83          123698      853         411         0.762       -1.3
# 84          122845      1.09e+03    505         0.799       -2.7
# 85          121756      1.5e+03     702         0.954       -4.4
# 86          120259      2.43e+03    1.11e+03    1.2         -6.2
# 87          117827      4e+03       2e+03       2.1         -inf
# 88          113828      6.21e+03    3.7e+03     3.44        -inf
# 89          107621      927         2.66e+03    4.36        -inf
# 90          106694      2.06e+03    1.99e+03    1.48        -inf
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 186
# Cholesky failed at 185
# Cholesky failed at 179
# 91          104637      14.1        14.6        0.0606      5.0
# 92          104623      14.1        13.9        0.0648      4.8
# 93          104609      28.5        31.1        0.112       4.4
# 94          104581      42          70          0.222       3.8
# 95          104539      81.4        76.4        0.269       3.0
# 96          104457      56.5        68.5        0.272       2.0
# 97          104401      50.9        44.3        0.348       0.7
# 98          104350      14.9        10.9        0.266       -0.7
# 99          104335      7.2         4.66        0.0957      -2.3
# EXIT : max(c) < tolConst
# 827.3883108109859

# %%
plt.subplot(131)
fS = 18
plt.plot(x[:,0], x[:,1], linewidth=2.0)
plt.plot(np.linspace(0,3,10),np.linspace(0,3,10))
plt.plot(x_t[0],x_t[1],"o")
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([0, 4.0, 0, 4.0])
plt.xlabel('X (m)', fontsize = fS)
plt.ylabel('Y (m)', fontsize = fS)
plt.show()
plt.subplot(121)
plt.plot(np.array(range(N))*0.1, u[:,0], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('v (m/s)', fontsize = fS)
plt.subplot(122)
plt.plot(np.array(range(N))*0.1, u[:,1], linewidth=2.0)
plt.xlabel('time (s)', fontsize = fS)
plt.ylabel('w (rad/s)', fontsize = fS)
plt.show()

# %%
lam = np.random.rand(3,1,1)
print lam
ineq_c = np.random.rand(3,1)
print ineq_c
ineq_c_mat = np.expand_dims(ineq_c,axis=2)
print ineq_c_mat
print_np( np.squeeze( np.matmul( np.transpose( np.expand_dims(np.diagonal(lam,0,2,1),2),(0,2,1)) , ineq_c_mat)))

# %%
0.97520549 * 0.64474434 + 0.10725643 * 0.26363584

# %%
A = np.ones((3,1,2))
B = np.ones((3,2,1))
np.diag
Mu = np.tile(np.identity(2),(3,1,1))
temp = np.tile(np.identity(2),(3,1,1))
print_np(Mu)
const = np.random.rand(3,2)
flag_const = const < 0.5
flag_const1 = const < 0.3
print_np(flag_const)
print_np(flag_const1)
print np.logical_or(flag_const,flag_const1)
# cc = np.expand_dims(flag_const,2) * Mu
# print cc

# %%
print_np( np.transpose( np.expand_dims(np.diagonal(lam,0,2,1),2),(0,2,1)) )

# %%
import antigravity

# %%
np.max((np.ones(1),np.ones(1)))

# %%
a = np.ones(1)
print_np(a)
print np.squeeze(a)
